# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

# %%
x = np.linspace(0, 1, 101)
y = np.linspace(0, 1, 121)
t = np.linspace(0, 2, 201)

xv, yv, tv = np.meshgrid(x, y, t)
z = (2*xv + yv)*np.exp(-2*tv)

# %%
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xv[:,:,0], yv[:,:,0], z[:,:,0], cmap=cm.coolwarm)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.view_init(elev=15, azim=0)

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')
ax.set_zlim((0, 3))

line, = ax.plot_surface(0*xv[:,:,0], 0*xv[:,:,0], 0*xv[:,:,0])



def init():
    line.set_data([], [], [])
    return (line,)

def animate(i):
    xi = xv[:,:,i]
    yi = yv[:,:,i]
    zi = zv[:,:,i]
    line.set_data(xi,yi,zi)
    
    return (line,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e45258ac6755> in <module>
#       3 ax.set_zlim((0, 3))
#       4
# ----> 5 line, = ax.plot_surface(0*xv[:,:,0], 0*xv[:,:,0], 0*xv[:,:,0])
#       6
#       7
#
# TypeError: cannot unpack non-iterable Poly3DCollection object
